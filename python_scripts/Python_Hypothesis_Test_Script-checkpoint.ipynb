# %%
import pandas as pd
import matplotlib.pyplot as plt
import scikit_posthocs as sp
from scipy.stats import kruskal

print("success")
# Out:
# success

# %%
df = pd.read_csv("export_table_dataset.csv")

print(df)
print(df["postcode_area"].value_counts())
# Out:
#      property_type  bedrooms  \
# 0             Flat         2
# 1             Flat         2
# 2         Detached         4
# 3             Flat         2
# 4    Semi-Detached         3
# ..             ...       ...
# 831           Flat         3
# 832           Flat         2
# 833       Detached         5
# 834           Flat         2
# 835           Flat         1
#
#                                                address    price  \
# 0    Flat 15, 1, Meggetland View, Slateford, Edinbu...   285000
# 1    Flat 26, 1, Drybrough Crescent, Craigmillar, E...   210000
# 2                15, Blackford Road, Edinburgh EH9 2DT  1710000
# 3    1f1, 17, Millar Crescent, Morningside, Edinbur...   420500
# 4    34, Tobias Street, Greendykes, Edinburgh EH16 4WG   270000
# ..                                                 ...      ...
# 831  10a, Riversdale Crescent, Saughtonhall, Edinbu...   625000
# 832  Flat 3, 11, Western Harbour Midway, Newhaven, ...   300000
# 833  61, East Craigs Wynd, North Gyle, Edinburgh EH...  1035000
# 834  2f2, 6, Belhaven Terrace, Morningside, Edinbur...   332000
# 835  53, Watson Crescent, Polwarth, Edinburgh EH11 1EW    62000
#
#      normalised_price        date  \
# 0              142500  2026-04-30
# 1              105000  2026-04-30
# 2              427500  2026-04-30
# 3              210250  2026-04-30
# 4               90000  2026-04-30
# ..                ...         ...
# 831            208333  2026-03-25
# 832            150000  2026-03-25
# 833            207000  2026-03-25
# 834            166000  2026-03-25
# 835             62000  2026-03-25
#
#                                                    url  postcode  \
# 0    https://www.rightmove.co.uk/house-prices/detai...  EH14 1XS
# 1    https://www.rightmove.co.uk/house-prices/detai...  EH16 4FB
# 2    https://www.rightmove.co.uk/house-prices/detai...   EH9 2DT
# 3    https://www.rightmove.co.uk/house-prices/detai...  EH10 5HN
# 4    https://www.rightmove.co.uk/house-prices/detai...  EH16 4WG
# ..                                                 ...       ...
# 831  https://www.rightmove.co.uk/house-prices/detai...  EH12 5QX
# 832  https://www.rightmove.co.uk/house-prices/detai...   EH6 6LG
# 833  https://www.rightmove.co.uk/house-prices/detai...  EH12 8HJ
# 834  https://www.rightmove.co.uk/house-prices/detai...  EH10 5HZ
# 835  https://www.rightmove.co.uk/house-prices/detai...  EH11 1EW
#
#     postcode_area                                          main_area
# 0            EH14  Slateford, Longstone, Wester Hailes, Juniper G...
# 1            EH16  Liberton, Cameron Toll, Craigmillar, Niddrie, ...
# 2             EH9  Marchmont, The Grange, Blackford, Sciennes, Ne...
# 3            EH10  Bruntsfield, Morningside, Fairmilehead, Braid ...
# 4            EH16  Liberton, Cameron Toll, Craigmillar, Niddrie, ...
# ..            ...                                                ...
# 831          EH12  Haymarket, Murrayfield, Roseburn, Corstorphine...
# 832           EH6            Leith, The Shore, Leith Links, Newhaven
# 833          EH12  Haymarket, Murrayfield, Roseburn, Corstorphine...
# 834          EH10  Bruntsfield, Morningside, Fairmilehead, Braid ...
# 835          EH11  Haymarket, Dalry, Gorgie, Stenhouse, Sighthill...
#
# [836 rows x 10 columns]
# postcode_area
# EH6     124
# EH4      88
# EH11     77
# EH7      70
# EH12     66
# EH10     63
# EH3      51
# EH16     48
# EH14     46
# EH5      39
# EH8      36
# EH15     34
# EH17     32
# EH9      25
# EH13     18
# EH1      10
# EH2       4
# EH21      4
# EH30      1
# Name: count, dtype: int64

# %%
summary = df.groupby("postcode_area")["normalised_price"].agg(["count", "mean", "median", "std", "min", "max"]) 

print(summary)
# Out:
#                count           mean    median            std     min      max
# postcode_area
# EH1               10  173239.600000  155000.0   93543.533554   22875   315000
# EH10              63  196688.015873  178657.0   68887.772515  110000   503700
# EH11              77  125761.675325  120000.0   45814.764717   50000   288000
# EH12              66  172212.272727  151666.5  138389.652576   76666  1200000
# EH13              18  131301.777778  119750.0   67777.026334   55000   310000
# EH14              46  123761.739130  121750.0   38687.219690   36250   221875
# EH15              34  151182.441176  138750.0   79077.523199   65068   500000
# EH16              48  120649.562500  105250.0   41786.676685   65000   270000
# EH17              32  101869.625000  102166.0   19295.729387   65666   148500
# EH2                4  260847.500000  276695.0   90846.517224  140000   350000
# EH21               4  109928.250000  107981.5    6059.545548  105000   118750
# EH3               51  225763.627451  214166.0   87864.659799   94750   562500
# EH30               1  120000.000000  120000.0            NaN  120000   120000
# EH4               88  156418.772727  153416.5   62154.632206   41000   323750
# EH5               39  131895.794872  112500.0   71596.886820   57500   475000
# EH6              124  141506.693548  135000.0   41579.717281   50375   262913
# EH7               70  158895.071429  152375.0   57737.300901   65000   350000
# EH8               36  142391.194444  136750.0   50996.631194   14500   257500
# EH9               25  199178.520000  160000.0   95205.536202   50432   427500

# %%
postcode = "EH4"

prices = df[
    df["postcode_area"] == postcode
]["price"].dropna()

plt.hist(prices, bins=10)

plt.xlabel("House Price")
plt.ylabel("Frequency")
plt.title(f"House Prices in {postcode}")

plt.show()

# %%
postcode_areas = df["postcode_area"].dropna().unique()

# Create one subplot for each postcode area
fig, axes = plt.subplots(
    nrows=len(postcode_areas),
    ncols=1,
    figsize=(10, 5 * len(postcode_areas))
)

for ax, area in zip(axes, postcode_areas):

    prices = df[
        df["postcode_area"] == area
    ]["price"].dropna()

    if len(prices) >= 1:

        ax.hist(prices, bins=10)

        ax.set_xlabel("House Price")
        ax.set_ylabel("Frequency")
        ax.set_title(f"House Prices - {area}")

plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['property_type', 'bedrooms', 'address', 'price', 'normalised_price',
#        'date', 'url', 'postcode', 'postcode_area', 'main_area'],
#       dtype='object')

# %%
area_counts = df["postcode_area"].value_counts()

valid_areas = area_counts[
    area_counts >= 10
].index

df_test = df[
    df["postcode_area"].isin(valid_areas)
].copy()

print("\nPostcode areas included in statistical tests:")
print(df_test["postcode_area"].value_counts().sort_index())
# Out:
# Postcode areas included in statistical tests:
# postcode_area
# EH1      10
# EH10     63
# EH11     77
# EH12     66
# EH13     18
# EH14     46
# EH15     34
# EH16     48
# EH17     32
# EH3      51
# EH4      88
# EH5      39
# EH6     124
# EH7      70
# EH8      36
# EH9      25
# Name: count, dtype: int64

# %%
groups = []

for area, group in df_test.groupby("postcode_area"):

    prices = group["price"].dropna()

    groups.append(prices)

    print(area, len(prices))
# Out:
# EH1 10
# EH10 63
# EH11 77
# EH12 66
# EH13 18
# EH14 46
# EH15 34
# EH16 48
# EH17 32
# EH3 51
# EH4 88
# EH5 39
# EH6 124
# EH7 70
# EH8 36
# EH9 25

# %%
#for area, group in df.groupby("postcode_area"):

#    prices = group["price"].dropna()

#    if len(prices) >= 10:
#        print(area, len(prices))

# %%
statistic, p_value = kruskal(*groups)

print("\nKruskal-Wallis Test")
print("-------------------")
print("Statistic:", statistic)
print("P-value:", p_value)
# Out:
# Kruskal-Wallis Test
# -------------------
# Statistic: 156.86382378498212
# P-value: 1.0388805102912975e-25

# %%
posthoc = sp.posthoc_dunn(
    df_test,
    val_col="price",
    group_col="postcode_area",
    p_adjust="bonferroni"
)

print("\nDunn's Test:")
print(posthoc)
# Out:
# Dunn's Test:
#           EH1     EH10     EH11     EH12     EH13     EH14     EH15     EH16  \
# EH1  1.000000 0.283740 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000
# EH10 0.283740 1.000000 0.000000 0.003899 0.775401 0.000007 0.004787 0.000000
# EH11 1.000000 0.000000 1.000000 0.000000 0.009979 0.019024 0.002120 1.000000
# EH12 1.000000 0.003899 0.000000 1.000000 1.000000 1.000000 1.000000 0.378232
# EH13 1.000000 0.775401 0.009979 1.000000 1.000000 1.000000 1.000000 1.000000
# EH14 1.000000 0.000007 0.019024 1.000000 1.000000 1.000000 1.000000 1.000000
# EH15 1.000000 0.004787 0.002120 1.000000 1.000000 1.000000 1.000000 1.000000
# EH16 1.000000 0.000000 1.000000 0.378232 1.000000 1.000000 1.000000 1.000000
# EH17 1.000000 0.000217 0.071987 1.000000 1.000000 1.000000 1.000000 1.000000
# EH3  1.000000 0.938382 0.000000 1.000000 1.000000 0.782076 1.000000 0.010057
# EH4  1.000000 0.000493 0.000000 1.000000 1.000000 1.000000 1.000000 0.364484
# EH5  1.000000 0.000000 0.689450 1.000000 1.000000 1.000000 1.000000 1.000000
# EH6  1.000000 0.000000 0.012584 0.282742 1.000000 1.000000 1.000000 1.000000
# EH7  1.000000 0.000006 0.000116 1.000000 1.000000 1.000000 1.000000 1.000000
# EH8  1.000000 0.000001 0.991870 1.000000 1.000000 1.000000 1.000000 1.000000
# EH9  1.000000 1.000000 0.000000 1.000000 1.000000 0.121152 1.000000 0.002280
#
#          EH17      EH3      EH4      EH5      EH6      EH7      EH8      EH9
# EH1  1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000
# EH10 0.000217 0.938382 0.000493 0.000000 0.000000 0.000006 0.000001 1.000000
# EH11 0.071987 0.000000 0.000000 0.689450 0.012584 0.000116 0.991870 0.000000
# EH12 1.000000 1.000000 1.000000 1.000000 0.282742 1.000000 1.000000 1.000000
# EH13 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000
# EH14 1.000000 0.782076 1.000000 1.000000 1.000000 1.000000 1.000000 0.121152
# EH15 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000
# EH16 1.000000 0.010057 0.364484 1.000000 1.000000 1.000000 1.000000 0.002280
# EH17 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 0.330851
# EH3  1.000000 1.000000 1.000000 0.094289 0.003598 1.000000 0.105979 1.000000
# EH4  1.000000 1.000000 1.000000 1.000000 0.215678 1.000000 1.000000 1.000000
# EH5  1.000000 0.094289 1.000000 1.000000 1.000000 1.000000 1.000000 0.016193
# EH6  1.000000 0.003598 0.215678 1.000000 1.000000 1.000000 1.000000 0.001492
# EH7  1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 1.000000 0.269700
# EH8  1.000000 0.105979 1.000000 1.000000 1.000000 1.000000 1.000000 0.017824
# EH9  0.330851 1.000000 1.000000 0.016193 0.001492 0.269700 0.017824 1.000000

# %%
print(groups)
# Out:
# [3       420500
# 13      450000
# 15     1575000
# 17      618600
# 37      412551
#         ...
# 764     650000
# 783     541000
# 786     670000
# 790     485000
# 834     332000
# Name: price, Length: 63, dtype: int64, 9      242500
# 11     192000
# 21     197400
# 28     230000
# 38     440000
#         ...
# 779    186000
# 802    185000
# 826    235000
# 827    140000
# 835     62000
# Name: price, Length: 77, dtype: int64, 16      600000
# 35      299995
# 39      326000
# 76      657000
# 84      328500
#         ...
# 767     260459
# 808     205000
# 825     400005
# 831     625000
# 833    1035000
# Name: price, Length: 66, dtype: int64, 0      285000
# 8      285000
# 49     530000
# 58     242000
# 63     315000
# 68     170000
# 87     187000
# 95     560000
# 107    290211
# 108    272850
# 130    245723
# 165    295000
# 182    185000
# 215    192000
# 217    175000
# 248    160000
# 265    330000
# 321    285000
# 329    282000
# 337    303000
# 347    500000
# 415    486500
# 432    245000
# 457    225500
# 551    148000
# 589    700000
# 591    297000
# 628    310000
# 647    285500
# 649    499995
# 666    190000
# 667    682775
# 672    343000
# 675    278500
# 701    360000
# 722    186500
# 730    155000
# 745    185000
# 781    155000
# 787    230000
# 806    211000
# 809    145000
# 821    125000
# 822    260000
# 823    443750
# 828    600000
# Name: price, dtype: int64, 25      662250
# 29      225000
# 62      421000
# 162     482500
# 168     905000
# 184     210000
# 221     340000
# 261     483000
# 288     351000
# 340     185000
# 341     270000
# 366     165000
# 378    1000000
# 382     233000
# 400     300000
# 416     150000
# 437     158000
# 439     355000
# 476     220000
# 500     230000
# 511     165000
# 530     430000
# 542     130136
# 554     405000
# 608     162270
# 622     365000
# 625     265000
# 688     285000
# 705     280000
# 750     240000
# 762    1100000
# 777     590000
# 784     192500
# 789     345000
# Name: price, dtype: int64, 1      210000
# 4      270000
# 12     235000
# 14     210000
# 36     225000
# 45     205000
# 54     193500
# 56     156000
# 64     425000
# 123    165000
# 142    175500
# 183    410000
# 218    236000
# 229    196150
# 237    370000
# 238    980000
# 241    277000
# 245    185101
# 260    265000
# 263    155000
# 267    300000
# 293    322000
# 326    153000
# 332    315000
# 357    225000
# 371    211000
# 391    368995
# 404    135000
# 431    235995
# 436    266800
# 503    234000
# 516    365000
# 583    760000
# 611    270000
# 615    195000
# 634    210000
# 653    190000
# 654    167000
# 658    272000
# 683    347000
# 737    170000
# 754    201000
# 782    130000
# 791    260000
# 796    470000
# 800    182500
# 807    229995
# 814    599000
# Name: price, dtype: int64, 34     320000
# 131    277000
# 136    298000
# 219    308000
# 226    320008
# 227    310250
# 281    305000
# 299    310000
# 302    420000
# 313    426000
# 327    207000
# 375    290000
# 426    215000
# 433    203000
# 435    375000
# 438    188000
# 462    208000
# 505    148500
# 532    245000
# 581    429995
# 582    213000
# 612    295000
# 613    270084
# 632    235000
# 638    316500
# 663    280000
# 712    235000
# 720    325000
# 721    242442
# 734    292000
# 746    131333
# 798    175000
# Name: price, dtype: int64, 6       310000
# 7       620000
# 18      130000
# 27      212507
# 40      385000
# 65      245000
# 72      675000
# 77      235722
# 125     255000
# 126     217500
# 148     284000
# 169     265000
# 179     317500
# 197     410000
# 223     415000
# 247     475000
# 298     450000
# 300     725000
# 304     415000
# 325     330000
# 339     265000
# 354     448500
# 379     260000
# 392     257000
# 424     296000
# 442     262538
# 447     388269
# 454     500000
# 483     320000
# 488     730000
# 502     379000
# 519     642500
# 525     236000
# 556    2250000
# 558     385000
# 584     545450
# 594     230000
# 617     263000
# 656     360000
# 685     575000
# 687     218500
# 690     360000
# 713     185000
# 731     185000
# 738     388555
# 744     450000
# 759     825000
# 769     270000
# 785     625000
# 794     257000
# 795     265000
# Name: price, dtype: int64, 22      630000
# 41      730000
# 67     1295000
# 75      287222
# 93      345266
#         ...
# 780     240000
# 788     940191
# 793     185000
# 803     305000
# 812     179777
# Name: price, Length: 88, dtype: int64, 50      213000
# 53      314995
# 55      170000
# 97      255000
# 110     950000
# 121     695000
# 196     215000
# 209     215000
# 234     137000
# 246     261000
# 262     258217
# 278     248550
# 286     191200
# 289     268000
# 331     130000
# 356     180000
# 370     270000
# 398     236000
# 409     395000
# 419     190000
# 423     194500
# 467     385000
# 469     495700
# 480     196400
# 482     185100
# 561     158500
# 566     225000
# 595     220000
# 635     230000
# 646     175000
# 657     361000
# 696     225000
# 718     325000
# 735     223000
# 742     210000
# 743     385000
# 778     240000
# 805     420000
# 818    1275000
# Name: price, dtype: int64, 10     455000
# 24     216000
# 30     465000
# 42     299995
# 46     160000
#         ...
# 820    210000
# 824    155000
# 829    520000
# 830    251500
# 832    300000
# Name: price, Length: 124, dtype: int64, 23     314500
# 31     325000
# 48     203168
# 60     245000
# 71     172500
#         ...
# 749    291000
# 766    247500
# 775    408000
# 797    280000
# 816    310000
# Name: price, Length: 70, dtype: int64, 5      168000
# 19     249500
# 20     260000
# 33     210210
# 100    175000
# 106    237500
# 122    375000
# 163    810000
# 176    285000
# 207    435500
# 214    160000
# 224    175000
# 249    230000
# 292    325000
# 309    225000
# 311    375000
# 318    218500
# 335    289286
# 361    405000
# 362    350000
# 394    438700
# 449    233333
# 451    167000
# 507    136000
# 600    242000
# 605    155000
# 607    385000
# 627    201000
# 630    388000
# 681    287500
# 684    216000
# 698    275000
# 708    220000
# 724    257500
# 801    167500
# 819     29000
# Name: price, dtype: int64]
